# %% [markdown]
# <a href="https://colab.research.google.com/github/hilaltekgz/AyrikSistemlerlcinlleriOlasilik/blob/main/215112017HilalTekgoz_Odev1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Güvercin Yuvası İlkesi**
#
# Gauss'un fikrine göre güvercin beslediğimizi düşünürsek, her akşam yuvalarına dönecek güvercinlerimiz var demektir. Eğer güvercinlerimizin sayısı (n) yuva sayısından (m) fazla ya da büyük eşit ise en az bir yuvada birden fazla güvercin olacaktır.
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
import math

def guvercinyasasiilkesi(x,y):
      return math.ceil(x/y)


yuva = int(input("Yuva Sayısı Giriniz: "))
guvercin = int(input("Güvercin Sayısı Giriniz: "))
result = guvercinyasasiilkesi(guvercin,yuva)
print("En az bir yuva ",result," güvercin içerir.")
# Out:
# Yuva Sayısı Giriniz: 3
# Güvercin Sayısı Giriniz: 4
# En az bir yuva  2  güvercin içerir.
